# %% [markdown]
# # COVID en la CDMX

# %% [markdown]
# ## Casos de COVID, personas hospitalizadas y capacidad de hospitales

# %% [markdown]
# ### Carlos Eduardo Peña Muñoz - A00826254

# %%
#pip install xlrd

# %%
#pip install openpyxl

# %%
#pip install pandas

# %%
#pip install numpy

# %%
#pip install matplotlib

# %%
#pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls presentacion
# Out:
# capacidadhospitalaria.csv  diccionario.xlsx
# casospositivos.csv         personashospitalizadas.csv

# %% [markdown]
# ### Base de Datos casospositivos.csv

# %%
df = pd.read_csv('presentacion/casospositivos.csv')
df.head()
# Out:
#   fecha_toma_muestra  pruebas_totales  positivos_totales  \
# 0           05/03/20               69                  1
# 1           13/03/20               57                  2
# 2           19/03/20               67                  3
# 3           24/03/20               66                  1
# 4           26/03/20               54                  1
#
#    pruebas_totales_cdmx  positivos_totales_cdmx  tasa_positividad  \
# 0                    52                       1          0.014493
# 1                    46                       1          0.035088
# 2                    67                       3          0.044776
# 3                    60                       1          0.015152
# 4                    50                       1          0.018519
#
#    tasa_positividad_cdmx
# 0               0.019231
# 1               0.021739
# 2               0.044776
# 3               0.016667
# 4               0.020000

# %%
df.drop(['pruebas_totales','tasa_positividad','pruebas_totales',],
        axis = 1,
        inplace = True)
df.columns
# Out:
# Index(['fecha_toma_muestra', 'positivos_totales', 'pruebas_totales_cdmx',
#        'positivos_totales_cdmx', 'tasa_positividad_cdmx'],
#       dtype='object')

# %%
df.rename(columns = {'pruebas_totales_cdmx' : 'Pruebas Totales',
                     'positivos_totales_cdmx' : 'Positivos Totales',
                     'fecha_toma_muestra' : 'Fecha',
                     'tasa_positividad_cdmx' : 'Tasa de Positividad',},
          inplace = True
         )

# %% [markdown]
# ### Estadistica de pruebas positivas en la CDMX

# %%
df.head()
# Out:
#       Fecha  positivos_totales  Pruebas Totales  Positivos Totales  \
# 0  05/03/20                  1               52                  1
# 1  13/03/20                  2               46                  1
# 2  19/03/20                  3               67                  3
# 3  24/03/20                  1               60                  1
# 4  26/03/20                  1               50                  1
#
#    Tasa de Positividad
# 0             0.019231
# 1             0.021739
# 2             0.044776
# 3             0.016667
# 4             0.020000

# %% [markdown]
# ### ¿Cual ha sido la tasa de positividad cada dia desde el año 2020 hasta el 2022?

# %%
myPivot = pd.pivot_table(df,
                         index = 'Fecha',
                         values = 'Tasa de Positividad',
                        )
myPivot
# Out:
#           Tasa de Positividad
# Fecha
# 01/01/21             0.284559
# 01/01/22             0.312971
# 01/02/21             0.196104
# 01/02/22             0.442721
# 01/03/21             0.166439
# ...                       ...
# 31/08/21             0.183061
# 31/10/20             0.338886
# 31/10/21             0.048114
# 31/12/20             0.261086
# 31/12/21             0.307851
#
# [709 rows x 1 columns]

# %% [markdown]
# ### Base de datos personashospitalizadas.csv

# %%
df = pd.read_csv('presentacion/personashospitalizadas.csv')
df.head()
# Out:
#         fecha   año    mes  dia  hospitalizados_totales  \
# 0  2020-03-24  2020  marzo   24                      50
# 1  2020-03-25  2020  marzo   25                     105
# 2  2020-03-26  2020  marzo   26                     128
# 3  2020-03-27  2020  marzo   27                     175
# 4  2020-03-28  2020  marzo   28                     257
#
#    hospitalizados_totales_cdmx  hospitalizados_totales_edomex  \
# 0                           50                              0
# 1                          105                              0
# 2                          128                              0
# 3                          175                              0
# 4                          257                              0
#
#    camas_intubados_totales  camas_intubados_cdmx  camas_intubados_edomex
# 0                       39                    39                       0
# 1                       33                    33                       0
# 2                       42                    42                       0
# 3                       60                    60                       0
# 4                       78                    78                       0

# %%
df.drop(['hospitalizados_totales','camas_intubados_totales','camas_intubados_edomex','hospitalizados_totales_edomex','año','mes','dia',],
        axis = 1,
        inplace = True)
df.columns
# Out:
# Index(['fecha', 'hospitalizados_totales_cdmx', 'camas_intubados_cdmx'], dtype='object')

# %%
df.rename(columns = {'fecha' : 'Fecha',
                     'hospitalizados_totales_cdmx' : 'Hospitalizados Totales',
                     'camas_intubados_cdmx' : 'Intubados',},
          inplace = True
         )

# %% [markdown]
# ### Cantidad de personas hospitalizadas que necesitaron intubación.

# %%
df.head()
# Out:
#         Fecha  Hospitalizados Totales  Intubados
# 0  2020-03-24                      50         39
# 1  2020-03-25                     105         33
# 2  2020-03-26                     128         42
# 3  2020-03-27                     175         60
# 4  2020-03-28                     257         78

# %% [markdown]
# ### Base de datos capacidadhospitalaria.csv

# %%
df = pd.read_csv('presentacion/capacidadhospitalaria.csv')
df.head()
# Out:
#         Fecha                                    Nombre_hospital Institucion  \
# 0  2020-06-13  HOSPITAL GENERAL DE ZONA C/MF 29 (S. JUAN ARAGÓN)        IMSS
# 1  2020-06-13       HOSPITAL GENERAL DE ZONA 47 (CDMX SUR) (IZP)        IMSS
# 2  2020-06-13                        UNIDAD MÓVIL TEMPORAL COVID        IMSS
# 3  2020-06-13                       HOSPITAL GENERAL REGIONAL 72        IMSS
# 4  2020-06-13                      HOSPITAL GENERAL REGIONAL 196        IMSS
#
#   Estatus_capacidad_hospitalaria Estatus_capacidad_UCI           Coordenadas
# 0                          Media                 Buena  19.465117,-99.085162
# 1                          Media                 Buena  19.357566,-99.054269
# 2                        Crítica                 Media  19.403082,-99.089177
# 3                          Media                 Media  19.356913,-98.990929
# 4                        Crítica                 Media  19.515133,-98.891450

# %%
df.drop(['Institucion','Estatus_capacidad_UCI','Coordenadas',],
        axis = 1,
        inplace = True)
df.columns
# Out:
# Index(['Fecha', 'Nombre_hospital', 'Estatus_capacidad_hospitalaria'], dtype='object')

# %%
df.rename(columns = {'Nombre_hospital' : 'Nombre Hospital',
                     'Estatus_capacidad_hospitalaria' : 'Estatus Capacidad Hospitalaria',},
          inplace = True
         )

# %% [markdown]
# ### Cúal fué la capacidad de cada hospital de la ciudad por fecha?

# %%
df.head()
# Out:
#         Fecha                                    Nombre Hospital  \
# 0  2020-06-13  HOSPITAL GENERAL DE ZONA C/MF 29 (S. JUAN ARAGÓN)
# 1  2020-06-13       HOSPITAL GENERAL DE ZONA 47 (CDMX SUR) (IZP)
# 2  2020-06-13                        UNIDAD MÓVIL TEMPORAL COVID
# 3  2020-06-13                       HOSPITAL GENERAL REGIONAL 72
# 4  2020-06-13                      HOSPITAL GENERAL REGIONAL 196
#
#   Estatus Capacidad Hospitalaria
# 0                          Media
# 1                          Media
# 2                        Crítica
# 3                          Media
# 4                        Crítica
